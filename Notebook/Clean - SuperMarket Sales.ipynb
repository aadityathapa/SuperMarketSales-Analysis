# %% [markdown]
# # Supermarket Sales

# %%
import pandas as pd

# %%
data_dir = '../Data/'

# %%
df = pd.read_csv(data_dir + 'SuperMarket Sales.csv')
df.columns.tolist()
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Unit price',
#  'Quantity',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'Payment',
#  'cogs',
#  'gross margin percentage',
#  'gross income',
#  'Rating']

# %%
df.rename(columns={
    'Invoice ID': 'Invoice_ID',
    'Customer type': 'Customer_Type',
    'Product line': 'Product_Line',
    'Unit price': 'Unit_Price',
    'Tax 5%': 'Tax_5_Percent',
    'cogs': 'COGS',
    'gross margin percentage': 'Gross_Margin_Percent',
    'gross income': 'Gross_Income',
}, inplace=True)

# %%
df.head()
# Out:
#     Invoice_ID Branch       City Customer_Type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product_Line  Unit_Price  Quantity  Tax_5_Percent     Total  \
# 0       Health and beauty       74.69         7        26.1415  548.9715
# 1  Electronic accessories       15.28         5         3.8200   80.2200
# 2      Home and lifestyle       46.33         7        16.2155  340.5255
# 3       Health and beauty       58.22         8        23.2880  489.0480
# 4       Sports and travel       86.31         7        30.2085  634.3785
#
#         Date   Time      Payment    COGS  Gross_Margin_Percent  Gross_Income  \
# 0   1/5/2019  13:08      Ewallet  522.83              4.761905       26.1415
# ...

# %%
df.to_csv(data_dir + "Clean - SuperMarket Sales.csv", index=False)
